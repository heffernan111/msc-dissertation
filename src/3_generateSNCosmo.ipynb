# %%
from pathlib import Path
import pandas as pd
import numpy as np
import sncosmo
from astropy.table import Table
import matplotlib.pyplot as plt
import warnings

project_root = Path.cwd().parent
print(f"Project root: {project_root}")
# Out:
# Project root: /Users/david/Code/msc

# %%
# User input: run folder name
folder_name = input("Enter the run folder name: ").strip()
run_folder = project_root / "runs" / folder_name

lightcurve_files = sorted(run_folder.glob("*_lightcurve.csv"))
print(f"Found {len(lightcurve_files)} lightcurve CSV(s) in {run_folder}")
for f in lightcurve_files:
    print(f"{f.name}")
# Out:
# Enter the run folder name: full_test_1
# Found 425 lightcurve CSV(s) in /Users/david/Code/msc/runs/full_test_1
# ZTF17aabtvsy_lightcurve.csv
# ZTF17aabvong_lightcurve.csv
# ZTF17aacldgo_lightcurve.csv
# ZTF17aadlxmv_lightcurve.csv
# ZTF18aaaonon_lightcurve.csv
# ZTF18aaaooqj_lightcurve.csv
# ZTF18aaaqexr_lightcurve.csv
# ZTF18aadlaxo_lightcurve.csv
# ZTF18aadxnul_lightcurve.csv
# ZTF18aadzfso_lightcurve.csv
# ZTF18aaeqjmc_lightcurve.csv
# ZTF18aaermez_lightcurve.csv
# ZTF18aafdigb_lightcurve.csv
# ZTF18aagkwgz_lightcurve.csv
# ZTF18aagtwyh_lightcurve.csv
# ZTF18aahfbqp_lightcurve.csv
# ZTF18aahtjsc_lightcurve.csv
# ZTF18aahvndq_lightcurve.csv
# ZTF18aailmnv_lightcurve.csv
# ZTF18aaisqmw_lightcurve.csv
# ZTF18aaiwzie_lightcurve.csv
# ZTF18aaiykoz_lightcurve.csv
# ZTF18aaizerg_lightcurve.csv
# ZTF18aajivpr_lightcurve.csv
# ZTF18aajkcdn_lightcurve.csv
# ZTF18aajkrxi_lightcurve.csv
# ZTF18aajpjdi_lightcurve.csv
# ZTF18aajvqye_lightcurve.csv
# ZTF18aakitiq_lightcurve.csv
# ZTF18aakiwbs_lightcurve.csv
# ZTF18aaklpdo_lightcurve.csv
# ZTF18aamvfeb_lightcurve.csv
# ZTF18aamxads_lightcurve.csv
# ZTF18aamzgzi_lightcurve.csv
# ZTF18aangpkx_lightcurve.csv
# ZTF18aanhpii_lightcurve.csv
# ZTF18aannern_lightcurve.csv
# ZTF18aansqom_lightcurve.csv
# ZTF18aansqov_lightcurve.csv
# ZTF18aansqun_lightcurve.csv
# ZTF18aanxlcr_lightcurve.csv
# ZTF18aanygjk_lightcurve.csv
# ZTF18aaoufjt_lightcurve.csv
# ZTF18aaovwbp_lightcurve.csv
# ZTF18aaoxrup_lightcurve.csv
# ZTF18aaqcqvr_lightcurve.csv
# ZTF18aaqedfj_lightcurve.csv
# ZTF18aaqjqqc_lightcurve.csv
# ZTF18aaqkcso_lightcurve.csv
# ZTF18aaqkqxi_lightcurve.csv
# ZTF18aaqldvl_lightcurve.csv
# ZTF18aaqnxjb_lightcurve.csv
# ZTF18aaqpeoq_lightcurve.csv
# ZTF18aaqqhis_lightcurve.csv
# ZTF18aaqskoy_lightcurve.csv
# ZTF18aaqydat_lightcurve.csv
# ZTF18aarbaba_lightcurve.csv
# ZTF18aarbgdn_lightcurve.csv
# ZTF18aarcypa_lightcurve.csv
# ZTF18aarikzk_lightcurve.csv
# ZTF18aarkwgc_lightcurve.csv
# ZTF18aarlukc_lightcurve.csv
# ZTF18aarmnnd_lightcurve.csv
# ZTF18aarunfu_lightcurve.csv
# ZTF18aarwxum_lightcurve.csv
# ZTF18aasdted_lightcurve.csv
# ZTF18aasprui_lightcurve.csv
# ZTF18aasrlze_lightcurve.csv
# ZTF18aatezaj_lightcurve.csv
# ZTF18aatgdph_lightcurve.csv
# ZTF18aatjfoe_lightcurve.csv
# ZTF18aatmlsy_lightcurve.csv
# ZTF18aatrkga_lightcurve.csv
# ZTF18aatrtkc_lightcurve.csv
# ZTF18aatwqed_lightcurve.csv
# ZTF18aauizcr_lightcurve.csv
# ZTF18aaunfqq_lightcurve.csv
# ZTF18aauotcv_lightcurve.csv
# ZTF18aavdwmh_lightcurve.csv
# ZTF18aaviawx_lightcurve.csv
# ZTF18aavrwhu_lightcurve.csv
# ZTF18aavryhc_lightcurve.csv
# ZTF18aavrzxp_lightcurve.csv
# ZTF18aavsilo_lightcurve.csv
# ZTF18aavvnzu_lightcurve.csv
# ZTF18aawfqax_lightcurve.csv
# ZTF18aawglif_lightcurve.csv
# ZTF18aawiilg_lightcurve.csv
# ZTF18aawitoj_lightcurve.csv
# ZTF18aawitry_lightcurve.csv
# ZTF18aawjywv_lightcurve.csv
# ZTF18aawlfnj_lightcurve.csv
# ZTF18aawlxls_lightcurve.csv
# ZTF18aawmeiw_lightcurve.csv
# ZTF18aawqjjj_lightcurve.csv
# ZTF18aawrotg_lightcurve.csv
# ZTF18aawseij_lightcurve.csv
# ZTF18aawurud_lightcurve.csv
# ZTF18aawxahl_lightcurve.csv
# ZTF18aawzens_lightcurve.csv
# ZTF18aaxcfbt_lightcurve.csv
# ZTF18aaxcntm_lightcurve.csv
# ZTF18aaxdrjn_lightcurve.csv
# ZTF18aaxeoqk_lightcurve.csv
# ZTF18aaxgwpl_lightcurve.csv
# ZTF18aaxhcam_lightcurve.csv
# ZTF18aaxkjmm_lightcurve.csv
# ZTF18aaxmhvk_lightcurve.csv
# ZTF18aaxokeg_lightcurve.csv
# ZTF18aaxqyki_lightcurve.csv
# ZTF18aaxsioa_lightcurve.csv
# ZTF18aaxvpsw_lightcurve.csv
# ZTF18aaxwjmp_lightcurve.csv
# ZTF18aaybfsd_lightcurve.csv
# ZTF18aaydmkh_lightcurve.csv
# ZTF18aayiahw_lightcurve.csv
# ZTF18aayidfz_lightcurve.csv
# ZTF18aayjvve_lightcurve.csv
# ZTF18aayjyub_lightcurve.csv
# ZTF18aayyqia_lightcurve.csv
# ZTF18aazabmh_lightcurve.csv
# ZTF18aazblzy_lightcurve.csv
# ZTF18aazhwnh_lightcurve.csv
# ZTF18aazixbw_lightcurve.csv
# ZTF18aazjqil_lightcurve.csv
# ZTF18aazjztm_lightcurve.csv
# ZTF18aazsabq_lightcurve.csv
# ZTF18abakunn_lightcurve.csv
# ZTF18abavruc_lightcurve.csv
# ZTF18abaxlpi_lightcurve.csv
# ZTF18abbpeqo_lightcurve.csv
# ZTF18abbqjds_lightcurve.csv
# ZTF18abbvsiv_lightcurve.csv
# ZTF18abcdzyc_lightcurve.csv
# ZTF18abcecfi_lightcurve.csv
# ZTF18abcflnz_lightcurve.csv
# ZTF18abckujg_lightcurve.csv
# ZTF18abckujq_lightcurve.csv
# ZTF18abcrtnq_lightcurve.csv
# ZTF18abcrxoj_lightcurve.csv
# ZTF18abcsgvj_lightcurve.csv
# ZTF18abcvush_lightcurve.csv
# ZTF18abcysdx_lightcurve.csv
# ZTF18abdbuty_lightcurve.csv
# ZTF18abdcudb_lightcurve.csv
# ZTF18abddrhd_lightcurve.csv
# ZTF18abdefet_lightcurve.csv
# ZTF18abdfazk_lightcurve.csv
# ZTF18abdfwur_lightcurve.csv
# ZTF18abdfydj_lightcurve.csv
# ZTF18abdgwxn_lightcurve.csv
# ZTF18abdiwpt_lightcurve.csv
# ZTF18abdkimx_lightcurve.csv
# ZTF18abdnffn_lightcurve.csv
# ZTF18abdnihj_lightcurve.csv
# ZTF18abdrmin_lightcurve.csv
# ZTF18abeecwe_lightcurve.csv
# ZTF18abeegsl_lightcurve.csv
# ZTF18abespgb_lightcurve.csv
# ZTF18abetehf_lightcurve.csv
# ZTF18abetejo_lightcurve.csv
# ZTF18abetewu_lightcurve.csv
# ZTF18abfbbyh_lightcurve.csv
# ZTF18abfchzq_lightcurve.csv
# ZTF18abfdupq_lightcurve.csv
# ZTF18abfeyey_lightcurve.csv
# ZTF18abffdjl_lightcurve.csv
# ZTF18abffdpa_lightcurve.csv
# ZTF18abfgygp_lightcurve.csv
# ZTF18abfhaji_lightcurve.csv
# ZTF18abfhryc_lightcurve.csv
# ZTF18abfwuwn_lightcurve.csv
# ZTF18abgkjff_lightcurve.csv
# ZTF18abgqkpc_lightcurve.csv
# ZTF18abgxkzx_lightcurve.csv
# ZTF18abgxvra_lightcurve.csv
# ZTF18abhbqbh_lightcurve.csv
# ZTF18abiczpm_lightcurve.csv
# ZTF18abifioh_lightcurve.csv
# ZTF18abimsyv_lightcurve.csv
# ZTF18abixkjh_lightcurve.csv
# ZTF18abixrei_lightcurve.csv
# ZTF18abjgyyr_lightcurve.csv
# ZTF18abjrfqx_lightcurve.csv
# ZTF18abjstcm_lightcurve.csv
# ZTF18abjtgdo_lightcurve.csv
# ZTF18abjtger_lightcurve.csv
# ZTF18abjvhec_lightcurve.csv
# ZTF18abjwahi_lightcurve.csv
# ZTF18abkhcrj_lightcurve.csv
# ZTF18abkhcwl_lightcurve.csv
# ZTF18abkifng_lightcurve.csv
# ZTF18abktphg_lightcurve.csv
# ZTF18abkudjo_lightcurve.csv
# ZTF18ablhvfr_lightcurve.csv
# ZTF18ablmflp_lightcurve.csv
# ZTF18ablongw_lightcurve.csv
# ZTF18ablqjul_lightcurve.csv
# ZTF18ablqkud_lightcurve.csv
# ZTF18ablqlzp_lightcurve.csv
# ZTF18ablqqqp_lightcurve.csv
# ZTF18ablrljh_lightcurve.csv
# ZTF18abltaxf_lightcurve.csv
# ZTF18ablwtkf_lightcurve.csv
# ZTF18abmjvpb_lightcurve.csv
# ZTF18abmjvuf_lightcurve.csv
# ZTF18abmjyvo_lightcurve.csv
# ZTF18abmmdif_lightcurve.csv
# ZTF18abmmkaz_lightcurve.csv
# ZTF18abmoung_lightcurve.csv
# ZTF18abmrhom_lightcurve.csv
# ZTF18abmwnov_lightcurve.csv
# ZTF18abmxahs_lightcurve.csv
# ZTF18abmxdhb_lightcurve.csv
# ZTF18abmxfrc_lightcurve.csv
# ZTF18abmxmsv_lightcurve.csv
# ZTF18abncimo_lightcurve.csv
# ZTF18abntsgz_lightcurve.csv
# ZTF18abnxhmc_lightcurve.csv
# ZTF18abobkii_lightcurve.csv
# ZTF18abokpvh_lightcurve.csv
# ZTF18abpamut_lightcurve.csv
# ZTF18abpaywm_lightcurve.csv
# ZTF18abpmmpo_lightcurve.csv
# ZTF18abpttky_lightcurve.csv
# ZTF18abqlpgq_lightcurve.csv
# ZTF18abquher_lightcurve.csv
# ZTF18abqyaix_lightcurve.csv
# ZTF18abqycit_lightcurve.csv
# ZTF18abrebsb_lightcurve.csv
# ZTF18abrfccm_lightcurve.csv
# ZTF18abrqedj_lightcurve.csv
# ZTF18abrzeym_lightcurve.csv
# ZTF18absdgon_lightcurve.csv
# ZTF18absnqyo_lightcurve.csv
# ZTF18absspcp_lightcurve.csv
# ZTF18abtnlik_lightcurve.csv
# ZTF18abugthp_lightcurve.csv
# ZTF18abwkzuc_lightcurve.csv
# ZTF18abxdkni_lightcurve.csv
# ZTF18abxhaop_lightcurve.csv
# ZTF18abxhsyn_lightcurve.csv
# ZTF18abxmxbh_lightcurve.csv
# ZTF18abxrqod_lightcurve.csv
# ZTF18abxtoqz_lightcurve.csv
# ZTF18abxtvqc_lightcurve.csv
# ZTF18abzzkyg_lightcurve.csv
# ZTF18acacnmr_lightcurve.csv
# ZTF18acaezsx_lightcurve.csv
# ZTF18acbvcmw_lightcurve.csv
# ZTF18acbvgqw_lightcurve.csv
# ZTF18acbxmvy_lightcurve.csv
# ZTF18acbxsap_lightcurve.csv
# ZTF18acbxsge_lightcurve.csv
# ZTF18acbyyff_lightcurve.csv
# ZTF18accjdgs_lightcurve.csv
# ZTF18acclexy_lightcurve.csv
# ZTF18accndxn_lightcurve.csv
# ZTF18accnlji_lightcurve.csv
# ZTF18accrorf_lightcurve.csv
# ZTF18accsawg_lightcurve.csv
# ZTF18accwjiu_lightcurve.csv
# ZTF18acdwuhy_lightcurve.csv
# ZTF18acdyypo_lightcurve.csv
# ZTF18aceexmi_lightcurve.csv
# ZTF18acefhxx_lightcurve.csv
# ZTF18acefxko_lightcurve.csv
# ZTF18acemhyb_lightcurve.csv
# ZTF18aceyjco_lightcurve.csv
# ZTF18aceynvm_lightcurve.csv
# ZTF18acfwmqj_lightcurve.csv
# ZTF18achxcsh_lightcurve.csv
# ZTF18acjxyak_lightcurve.csv
# ZTF18acmyxfx_lightcurve.csv
# ZTF18acnbenl_lightcurve.csv
# ZTF18acnbeuu_lightcurve.csv
# ZTF18acnnxor_lightcurve.csv
# ZTF18acpeemg_lightcurve.csv
# ZTF18acptgzz_lightcurve.csv
# ZTF18acpuxuh_lightcurve.csv
# ZTF18acqnzso_lightcurve.csv
# ZTF18acqqyah_lightcurve.csv
# ZTF18acqsfxh_lightcurve.csv
# ZTF18acqsztr_lightcurve.csv
# ZTF18acqxsyi_lightcurve.csv
# ZTF18acrcizr_lightcurve.csv
# ZTF18acrdmmw_lightcurve.csv
# ZTF18acrgunw_lightcurve.csv
# ZTF18acrknyn_lightcurve.csv
# ZTF18acrlmvt_lightcurve.csv
# ZTF18acrncou_lightcurve.csv
# ZTF18acrxppd_lightcurve.csv
# ZTF18acskxpn_lightcurve.csv
# ZTF18acslbve_lightcurve.csv
# ZTF18acslpba_lightcurve.csv
# ZTF18acsofdh_lightcurve.csv
# ZTF18acsohut_lightcurve.csv
# ZTF18acspjqd_lightcurve.csv
# ZTF18acsremz_lightcurve.csv
# ZTF18acsxpmp_lightcurve.csv
# ZTF18acsxusq_lightcurve.csv
# ZTF18acsyanq_lightcurve.csv
# ZTF18acsyzca_lightcurve.csv
# ZTF18acuefvt_lightcurve.csv
# ZTF18acuixmb_lightcurve.csv
# ZTF18acurlbj_lightcurve.csv
# ZTF18acusbdy_lightcurve.csv
# ZTF18acusbyf_lightcurve.csv
# ZTF18acuscgc_lightcurve.csv
# ZTF18acuscrr_lightcurve.csv
# ZTF18acusrws_lightcurve.csv
# ZTF18acvguyi_lightcurve.csv
# ZTF18acvwbos_lightcurve.csv
# ZTF18acvwmpw_lightcurve.csv
# ZTF18acwutbr_lightcurve.csv
# ZTF18acwwonp_lightcurve.csv
# ZTF18acwwowy_lightcurve.csv
# ZTF18acwyowc_lightcurve.csv
# ZTF18acxyarg_lightcurve.csv
# ZTF18acyaher_lightcurve.csv
# ZTF18acybdar_lightcurve.csv
# ZTF18acynmcp_lightcurve.csv
# ZTF18acynoro_lightcurve.csv
# ZTF18aczdetm_lightcurve.csv
# ZTF18aczeesl_lightcurve.csv
# ZTF18aczemzj_lightcurve.csv
# ZTF18aczenvx_lightcurve.csv
# ZTF18aczqtpt_lightcurve.csv
# ZTF18aczuwxb_lightcurve.csv
# ZTF18adaadmh_lightcurve.csv
# ZTF18adaimlf_lightcurve.csv
# ZTF18adaslwa_lightcurve.csv
# ZTF18adathpb_lightcurve.csv
# ZTF18adaylyq_lightcurve.csv
# ZTF18adazbol_lightcurve.csv
# ZTF18adazgdh_lightcurve.csv
# ZTF18adbadqp_lightcurve.csv
# ZTF18adbbhww_lightcurve.csv
# ZTF18adbckox_lightcurve.csv
# ZTF18adbntwo_lightcurve.csv
# ZTF18adbyxua_lightcurve.csv
# ZTF18adcdcrd_lightcurve.csv
# ZTF19aaagfme_lightcurve.csv
# ZTF19aaairqh_lightcurve.csv
# ZTF19aaarhtg_lightcurve.csv
# ZTF19aabmybj_lightcurve.csv
# ZTF19aabvfwn_lightcurve.csv
# ZTF19aabyheu_lightcurve.csv
# ZTF19aabyppp_lightcurve.csv
# ZTF19aabyuze_lightcurve.csv
# ZTF19aacgslb_lightcurve.csv
# ZTF19aacijie_lightcurve.csv
# ZTF19aacilht_lightcurve.csv
# ZTF19aacivvy_lightcurve.csv
# ZTF19aacxrzt_lightcurve.csv
# ZTF19aadnmgf_lightcurve.csv
# ZTF19aadnwvc_lightcurve.csv
# ZTF19aadnxat_lightcurve.csv
# ZTF19aadolpe_lightcurve.csv
# ZTF19aadoocn_lightcurve.csv
# ZTF19aadooun_lightcurve.csv
# ZTF19aadyijk_lightcurve.csv
# ZTF19aadyoqz_lightcurve.csv
# ZTF19aaeflme_lightcurve.csv
# ZTF19aaeicsm_lightcurve.csv
# ZTF19aaekvhn_lightcurve.csv
# ZTF19aaeopqn_lightcurve.csv
# ZTF19aaeoqkk_lightcurve.csv
# ZTF19aaezwmr_lightcurve.csv
# ZTF19aafmhcl_lightcurve.csv
# ZTF19aafnfyc_lightcurve.csv
# ZTF19aafwrhf_lightcurve.csv
# ZTF19aagmpeq_lightcurve.csv
# ZTF19aagmsrr_lightcurve.csv
# ZTF19aahjhoy_lightcurve.csv
# ZTF19aahsnmq_lightcurve.csv
# ZTF19aailexm_lightcurve.csv
# ZTF19aaillan_lightcurve.csv
# ZTF19aailltc_lightcurve.csv
# ZTF19aailqir_lightcurve.csv
# ZTF19aailqli_lightcurve.csv
# ZTF19aailteb_lightcurve.csv
# ZTF19aailuvj_lightcurve.csv
# ZTF19aajwdqt_lightcurve.csv
# ZTF19aajwhbc_lightcurve.csv
# ZTF19aajxhwa_lightcurve.csv
# ZTF19aajxwnz_lightcurve.csv
# ZTF19aakiwxx_lightcurve.csv
# ZTF19aakiyly_lightcurve.csv
# ZTF19aakjbej_lightcurve.csv
# ZTF19aaklbok_lightcurve.csv
# ZTF19aakljys_lightcurve.csv
# ZTF19aaklqod_lightcurve.csv
# ZTF19aaklquv_lightcurve.csv
# ZTF19aaknign_lightcurve.csv
# ZTF19aakocxy_lightcurve.csv
# ZTF19aakpfax_lightcurve.csv
# ZTF19aaksrgj_lightcurve.csv
# ZTF19aakthjl_lightcurve.csv
# ZTF19aakwifv_lightcurve.csv
# ZTF19aakzwao_lightcurve.csv
# ZTF19aalaxsa_lightcurve.csv
# ZTF19aalcwjt_lightcurve.csv
# ZTF19aalcyfd_lightcurve.csv
# ZTF19aaldqvh_lightcurve.csv
# ZTF19aaleptm_lightcurve.csv
# ZTF19aaljcsu_lightcurve.csv
# ZTF19aalpoff_lightcurve.csv
# ZTF19aaluprf_lightcurve.csv
# ZTF19aalveag_lightcurve.csv
# ZTF19aalxcyo_lightcurve.csv
# ZTF19aalxlpp_lightcurve.csv
# ZTF19aalyleg_lightcurve.csv
# ZTF19aalzmio_lightcurve.csv
# ZTF19aalzmiu_lightcurve.csv
# ZTF19aamaeve_lightcurve.csv
# ZTF19aambfxc_lightcurve.csv
# ZTF19aamgokq_lightcurve.csv
# ZTF19aamgttu_lightcurve.csv
# ZTF19aamhhae_lightcurve.csv
# ZTF19aamhhey_lightcurve.csv
# ZTF19aamhhgu_lightcurve.csv
# ZTF19aamhhyo_lightcurve.csv
# ZTF19aamhlnl_lightcurve.csv
# ZTF19aamhqej_lightcurve.csv

# %%
filter_map = {"g": "ztfg", "r": "ztfr"}
# Redshift per object from ztf_cleansed.csv; fit t0, x0, x1, c only
fit_params = ["t0", "x0", "x1", "c"]
bounds = {"x1": (-3, 3), "c": (-0.3, 0.3)}

all_results = []

# %%
# Load ztf_cleansed.csv
ztf_cleansed_path = project_root / "ztf_cleansed.csv"
ztf_meta = pd.read_csv(ztf_cleansed_path)
ztf_meta["ZTFID"] = ztf_meta["ZTFID"].astype(str).str.strip()

total_files = len(lightcurve_files)
completed = 0

for idx, lc_path in enumerate(lightcurve_files, 1):
    obj_id = lc_path.stem.replace("_lightcurve", "")
    print(f"[{idx}/{total_files}] Processing {obj_id}....")

    # Load cleaned lightcurve from downloadLasair (MJD, filter, forced_ujy, forced_ujy_error)
    df = pd.read_csv(lc_path)
    df["MJD"] = pd.to_numeric(df["MJD"], errors="coerce")
    df = df.dropna(subset=["MJD", "filter", "forced_ujy", "forced_ujy_error"])
    df["filter"] = df["filter"].astype(str).str.strip().str.lower()
    df = df[df["forced_ujy"].gt(0) & df["forced_ujy_error"].gt(0)].copy()

    if len(df) < 5:
        print(f"  Skip {obj_id}: too few points ({len(df)})")
        continue

    bands = [filter_map.get(f, f"ztf{f}") for f in df["filter"].values]
    data = Table({
        "time": df["MJD"].values,
        "band": bands,
        "flux": df["forced_ujy"].values,
        "fluxerr": df["forced_ujy_error"].values,
        "zp": np.full(len(df), 23.9),
        "zpsys": np.array(["ab"] * len(df)),
    })

    # Look up obj_id in the ZTFID column
    meta_row = ztf_meta.loc[ztf_meta["ZTFID"] == obj_id].iloc[0]
    redshift = float(meta_row["redshift"])
    A_V = float(pd.to_numeric(meta_row.get("A_V", 0), errors="coerce") or 0)
    ebv = A_V / 3.1  # E(B-V) from A_V with R_V = 3.1 (standard value for MW)

    # SALT2 + Milky Way dust (observer frame) using A_V from ztf_cleansed
    # effect_names=['mw'] gives parameter 'mwebv' (prefix 'mw' + dust param 'ebv')
    dust = sncosmo.F99Dust()
    model = sncosmo.Model(source="salt2", effects=[dust], effect_names=["mw"], effect_frames=["obs"])
    model.set(z=redshift, mwebv=ebv)

    try:
        with warnings.catch_warnings():
            warnings.simplefilter("ignore", RuntimeWarning)
            result, fitted_model = sncosmo.fit_lc(data, model, fit_params, bounds=bounds)
    except Exception as e:
        print(f"  Fit failed: {e}")
        continue

    row = {"object_id": obj_id, "chisq": result.chisq, "ndof": result.ndof, "z": redshift}
    for name, val in zip(result.param_names, result.parameters):
        row[name] = val
    if result.errors is not None:
        for name in result.param_names:
            if name in result.errors:
                row[f"{name}_err"] = result.errors[name]
    all_results.append(row)

    fig = sncosmo.plot_lc(data, model=fitted_model, errors=result.errors)
    plt.gcf().suptitle(obj_id)
    out_plot = run_folder / f"{lc_path.stem}_salt2.png"
    plt.savefig(out_plot, dpi=150, bbox_inches="tight")
    plt.close()
    completed += 1
    print(f"  Saved {out_plot.name}  ({completed}/{total_files} completed)")
# Out:
# [1/425] Processing ZTF17aabtvsy....
#   Saved ZTF17aabtvsy_lightcurve_salt2.png  (1/425 completed)
# [2/425] Processing ZTF17aabvong....
#   Saved ZTF17aabvong_lightcurve_salt2.png  (2/425 completed)
# [3/425] Processing ZTF17aacldgo....
#   Saved ZTF17aacldgo_lightcurve_salt2.png  (3/425 completed)
# [4/425] Processing ZTF17aadlxmv....
#   Saved ZTF17aadlxmv_lightcurve_salt2.png  (4/425 completed)
# [5/425] Processing ZTF18aaaonon....
#   Saved ZTF18aaaonon_lightcurve_salt2.png  (5/425 completed)
# [6/425] Processing ZTF18aaaooqj....
#   Saved ZTF18aaaooqj_lightcurve_salt2.png  (6/425 completed)
# [7/425] Processing ZTF18aaaqexr....
#   Saved ZTF18aaaqexr_lightcurve_salt2.png  (7/425 completed)
# [8/425] Processing ZTF18aadlaxo....
#   Saved ZTF18aadlaxo_lightcurve_salt2.png  (8/425 completed)
# [9/425] Processing ZTF18aadxnul....
#   Skip ZTF18aadxnul: too few points (3)
# [10/425] Processing ZTF18aadzfso....
#   Saved ZTF18aadzfso_lightcurve_salt2.png  (9/425 completed)
# [11/425] Processing ZTF18aaeqjmc....
#   Saved ZTF18aaeqjmc_lightcurve_salt2.png  (10/425 completed)
# [12/425] Processing ZTF18aaermez....
#   Saved ZTF18aaermez_lightcurve_salt2.png  (11/425 completed)
# [13/425] Processing ZTF18aafdigb....
#   Saved ZTF18aafdigb_lightcurve_salt2.png  (12/425 completed)
# [14/425] Processing ZTF18aagkwgz....
#   Saved ZTF18aagkwgz_lightcurve_salt2.png  (13/425 completed)
# [15/425] Processing ZTF18aagtwyh....
#   Saved ZTF18aagtwyh_lightcurve_salt2.png  (14/425 completed)
# [16/425] Processing ZTF18aahfbqp....
#   Saved ZTF18aahfbqp_lightcurve_salt2.png  (15/425 completed)
# [17/425] Processing ZTF18aahtjsc....
#   Saved ZTF18aahtjsc_lightcurve_salt2.png  (16/425 completed)
# [18/425] Processing ZTF18aahvndq....
#   Saved ZTF18aahvndq_lightcurve_salt2.png  (17/425 completed)
# [19/425] Processing ZTF18aailmnv....
#   Saved ZTF18aailmnv_lightcurve_salt2.png  (18/425 completed)
# [20/425] Processing ZTF18aaisqmw....
#   Saved ZTF18aaisqmw_lightcurve_salt2.png  (19/425 completed)
# [21/425] Processing ZTF18aaiwzie....
#   Saved ZTF18aaiwzie_lightcurve_salt2.png  (20/425 completed)
# [22/425] Processing ZTF18aaiykoz....
#   Saved ZTF18aaiykoz_lightcurve_salt2.png  (21/425 completed)
# [23/425] Processing ZTF18aaizerg....
#   Saved ZTF18aaizerg_lightcurve_salt2.png  (22/425 completed)
# [24/425] Processing ZTF18aajivpr....
#   Saved ZTF18aajivpr_lightcurve_salt2.png  (23/425 completed)
# [25/425] Processing ZTF18aajkcdn....
#   Saved ZTF18aajkcdn_lightcurve_salt2.png  (24/425 completed)
# [26/425] Processing ZTF18aajkrxi....
#   Saved ZTF18aajkrxi_lightcurve_salt2.png  (25/425 completed)
# [27/425] Processing ZTF18aajpjdi....
#   Saved ZTF18aajpjdi_lightcurve_salt2.png  (26/425 completed)
# [28/425] Processing ZTF18aajvqye....
#   Saved ZTF18aajvqye_lightcurve_salt2.png  (27/425 completed)
# [29/425] Processing ZTF18aakitiq....
#   Saved ZTF18aakitiq_lightcurve_salt2.png  (28/425 completed)
# [30/425] Processing ZTF18aakiwbs....
#   Saved ZTF18aakiwbs_lightcurve_salt2.png  (29/425 completed)
# [31/425] Processing ZTF18aaklpdo....
#   Saved ZTF18aaklpdo_lightcurve_salt2.png  (30/425 completed)
# [32/425] Processing ZTF18aamvfeb....
#   Saved ZTF18aamvfeb_lightcurve_salt2.png  (31/425 completed)
# [33/425] Processing ZTF18aamxads....
#   Saved ZTF18aamxads_lightcurve_salt2.png  (32/425 completed)
# [34/425] Processing ZTF18aamzgzi....
#   Saved ZTF18aamzgzi_lightcurve_salt2.png  (33/425 completed)
# [35/425] Processing ZTF18aangpkx....
#   Saved ZTF18aangpkx_lightcurve_salt2.png  (34/425 completed)
# [36/425] Processing ZTF18aanhpii....
#   Saved ZTF18aanhpii_lightcurve_salt2.png  (35/425 completed)
# [37/425] Processing ZTF18aannern....
#   Saved ZTF18aannern_lightcurve_salt2.png  (36/425 completed)
# [38/425] Processing ZTF18aansqom....
#   Saved ZTF18aansqom_lightcurve_salt2.png  (37/425 completed)
# [39/425] Processing ZTF18aansqov....
#   Saved ZTF18aansqov_lightcurve_salt2.png  (38/425 completed)
# [40/425] Processing ZTF18aansqun....
#   Saved ZTF18aansqun_lightcurve_salt2.png  (39/425 completed)
# [41/425] Processing ZTF18aanxlcr....
#   Saved ZTF18aanxlcr_lightcurve_salt2.png  (40/425 completed)
# [42/425] Processing ZTF18aanygjk....
#   Saved ZTF18aanygjk_lightcurve_salt2.png  (41/425 completed)
# [43/425] Processing ZTF18aaoufjt....
#   Saved ZTF18aaoufjt_lightcurve_salt2.png  (42/425 completed)
# [44/425] Processing ZTF18aaovwbp....
#   Saved ZTF18aaovwbp_lightcurve_salt2.png  (43/425 completed)
# [45/425] Processing ZTF18aaoxrup....
#   Saved ZTF18aaoxrup_lightcurve_salt2.png  (44/425 completed)
# [46/425] Processing ZTF18aaqcqvr....
#   Saved ZTF18aaqcqvr_lightcurve_salt2.png  (45/425 completed)
# [47/425] Processing ZTF18aaqedfj....
#   Saved ZTF18aaqedfj_lightcurve_salt2.png  (46/425 completed)
# [48/425] Processing ZTF18aaqjqqc....
#   Saved ZTF18aaqjqqc_lightcurve_salt2.png  (47/425 completed)
# [49/425] Processing ZTF18aaqkcso....
#   Saved ZTF18aaqkcso_lightcurve_salt2.png  (48/425 completed)
# [50/425] Processing ZTF18aaqkqxi....
#   Saved ZTF18aaqkqxi_lightcurve_salt2.png  (49/425 completed)
# [51/425] Processing ZTF18aaqldvl....
#   Saved ZTF18aaqldvl_lightcurve_salt2.png  (50/425 completed)
# [52/425] Processing ZTF18aaqnxjb....
#   Saved ZTF18aaqnxjb_lightcurve_salt2.png  (51/425 completed)
# [53/425] Processing ZTF18aaqpeoq....
#   Saved ZTF18aaqpeoq_lightcurve_salt2.png  (52/425 completed)
# [54/425] Processing ZTF18aaqqhis....
#   Saved ZTF18aaqqhis_lightcurve_salt2.png  (53/425 completed)
# [55/425] Processing ZTF18aaqskoy....
#   Saved ZTF18aaqskoy_lightcurve_salt2.png  (54/425 completed)
# [56/425] Processing ZTF18aaqydat....
#   Saved ZTF18aaqydat_lightcurve_salt2.png  (55/425 completed)
# [57/425] Processing ZTF18aarbaba....
#   Saved ZTF18aarbaba_lightcurve_salt2.png  (56/425 completed)
# [58/425] Processing ZTF18aarbgdn....
#   Saved ZTF18aarbgdn_lightcurve_salt2.png  (57/425 completed)
# [59/425] Processing ZTF18aarcypa....
#   Saved ZTF18aarcypa_lightcurve_salt2.png  (58/425 completed)
# [60/425] Processing ZTF18aarikzk....
#   Saved ZTF18aarikzk_lightcurve_salt2.png  (59/425 completed)
# [61/425] Processing ZTF18aarkwgc....
#   Saved ZTF18aarkwgc_lightcurve_salt2.png  (60/425 completed)
# [62/425] Processing ZTF18aarlukc....
#   Saved ZTF18aarlukc_lightcurve_salt2.png  (61/425 completed)
# [63/425] Processing ZTF18aarmnnd....
#   Saved ZTF18aarmnnd_lightcurve_salt2.png  (62/425 completed)
# [64/425] Processing ZTF18aarunfu....
#   Saved ZTF18aarunfu_lightcurve_salt2.png  (63/425 completed)
# [65/425] Processing ZTF18aarwxum....
#   Saved ZTF18aarwxum_lightcurve_salt2.png  (64/425 completed)
# [66/425] Processing ZTF18aasdted....
#   Saved ZTF18aasdted_lightcurve_salt2.png  (65/425 completed)
# [67/425] Processing ZTF18aasprui....
#   Saved ZTF18aasprui_lightcurve_salt2.png  (66/425 completed)
# [68/425] Processing ZTF18aasrlze....
#   Saved ZTF18aasrlze_lightcurve_salt2.png  (67/425 completed)
# [69/425] Processing ZTF18aatezaj....
#   Saved ZTF18aatezaj_lightcurve_salt2.png  (68/425 completed)
# [70/425] Processing ZTF18aatgdph....
#   Saved ZTF18aatgdph_lightcurve_salt2.png  (69/425 completed)
# [71/425] Processing ZTF18aatjfoe....
#   Saved ZTF18aatjfoe_lightcurve_salt2.png  (70/425 completed)
# [72/425] Processing ZTF18aatmlsy....
#   Saved ZTF18aatmlsy_lightcurve_salt2.png  (71/425 completed)
# [73/425] Processing ZTF18aatrkga....
#   Saved ZTF18aatrkga_lightcurve_salt2.png  (72/425 completed)
# [74/425] Processing ZTF18aatrtkc....
#   Saved ZTF18aatrtkc_lightcurve_salt2.png  (73/425 completed)
# [75/425] Processing ZTF18aatwqed....
#   Saved ZTF18aatwqed_lightcurve_salt2.png  (74/425 completed)
# [76/425] Processing ZTF18aauizcr....
#   Saved ZTF18aauizcr_lightcurve_salt2.png  (75/425 completed)
# [77/425] Processing ZTF18aaunfqq....
#   Saved ZTF18aaunfqq_lightcurve_salt2.png  (76/425 completed)
# [78/425] Processing ZTF18aauotcv....
#   Saved ZTF18aauotcv_lightcurve_salt2.png  (77/425 completed)
# [79/425] Processing ZTF18aavdwmh....
#   Saved ZTF18aavdwmh_lightcurve_salt2.png  (78/425 completed)
# [80/425] Processing ZTF18aaviawx....
#   Saved ZTF18aaviawx_lightcurve_salt2.png  (79/425 completed)
# [81/425] Processing ZTF18aavrwhu....
#   Saved ZTF18aavrwhu_lightcurve_salt2.png  (80/425 completed)
# [82/425] Processing ZTF18aavryhc....
#   Saved ZTF18aavryhc_lightcurve_salt2.png  (81/425 completed)
# [83/425] Processing ZTF18aavrzxp....
#   Saved ZTF18aavrzxp_lightcurve_salt2.png  (82/425 completed)
# [84/425] Processing ZTF18aavsilo....
#   Saved ZTF18aavsilo_lightcurve_salt2.png  (83/425 completed)
# [85/425] Processing ZTF18aavvnzu....
#   Saved ZTF18aavvnzu_lightcurve_salt2.png  (84/425 completed)
# [86/425] Processing ZTF18aawfqax....
#   Saved ZTF18aawfqax_lightcurve_salt2.png  (85/425 completed)
# [87/425] Processing ZTF18aawglif....
#   Saved ZTF18aawglif_lightcurve_salt2.png  (86/425 completed)
# [88/425] Processing ZTF18aawiilg....
#   Saved ZTF18aawiilg_lightcurve_salt2.png  (87/425 completed)
# [89/425] Processing ZTF18aawitoj....
#   Saved ZTF18aawitoj_lightcurve_salt2.png  (88/425 completed)
# [90/425] Processing ZTF18aawitry....
#   Saved ZTF18aawitry_lightcurve_salt2.png  (89/425 completed)
# [91/425] Processing ZTF18aawjywv....
#   Saved ZTF18aawjywv_lightcurve_salt2.png  (90/425 completed)
# [92/425] Processing ZTF18aawlfnj....
#   Saved ZTF18aawlfnj_lightcurve_salt2.png  (91/425 completed)
# [93/425] Processing ZTF18aawlxls....
#   Saved ZTF18aawlxls_lightcurve_salt2.png  (92/425 completed)
# [94/425] Processing ZTF18aawmeiw....
#   Saved ZTF18aawmeiw_lightcurve_salt2.png  (93/425 completed)
# [95/425] Processing ZTF18aawqjjj....
#   Saved ZTF18aawqjjj_lightcurve_salt2.png  (94/425 completed)
# [96/425] Processing ZTF18aawrotg....
#   Saved ZTF18aawrotg_lightcurve_salt2.png  (95/425 completed)
# [97/425] Processing ZTF18aawseij....
#   Saved ZTF18aawseij_lightcurve_salt2.png  (96/425 completed)
# [98/425] Processing ZTF18aawurud....
#   Saved ZTF18aawurud_lightcurve_salt2.png  (97/425 completed)
# [99/425] Processing ZTF18aawxahl....
#   Saved ZTF18aawxahl_lightcurve_salt2.png  (98/425 completed)
# [100/425] Processing ZTF18aawzens....
#   Saved ZTF18aawzens_lightcurve_salt2.png  (99/425 completed)
# [101/425] Processing ZTF18aaxcfbt....
#   Saved ZTF18aaxcfbt_lightcurve_salt2.png  (100/425 completed)
# [102/425] Processing ZTF18aaxcntm....
#   Saved ZTF18aaxcntm_lightcurve_salt2.png  (101/425 completed)
# [103/425] Processing ZTF18aaxdrjn....
#   Saved ZTF18aaxdrjn_lightcurve_salt2.png  (102/425 completed)
# [104/425] Processing ZTF18aaxeoqk....
#   Saved ZTF18aaxeoqk_lightcurve_salt2.png  (103/425 completed)
# [105/425] Processing ZTF18aaxgwpl....
#   Saved ZTF18aaxgwpl_lightcurve_salt2.png  (104/425 completed)
# [106/425] Processing ZTF18aaxhcam....
#   Saved ZTF18aaxhcam_lightcurve_salt2.png  (105/425 completed)
# [107/425] Processing ZTF18aaxkjmm....
#   Saved ZTF18aaxkjmm_lightcurve_salt2.png  (106/425 completed)
# [108/425] Processing ZTF18aaxmhvk....
#   Saved ZTF18aaxmhvk_lightcurve_salt2.png  (107/425 completed)
# [109/425] Processing ZTF18aaxokeg....
#   Saved ZTF18aaxokeg_lightcurve_salt2.png  (108/425 completed)
# [110/425] Processing ZTF18aaxqyki....
#   Saved ZTF18aaxqyki_lightcurve_salt2.png  (109/425 completed)
# [111/425] Processing ZTF18aaxsioa....
#   Saved ZTF18aaxsioa_lightcurve_salt2.png  (110/425 completed)
# [112/425] Processing ZTF18aaxvpsw....
#   Saved ZTF18aaxvpsw_lightcurve_salt2.png  (111/425 completed)
# [113/425] Processing ZTF18aaxwjmp....
#   Saved ZTF18aaxwjmp_lightcurve_salt2.png  (112/425 completed)
# [114/425] Processing ZTF18aaybfsd....
#   Saved ZTF18aaybfsd_lightcurve_salt2.png  (113/425 completed)
# [115/425] Processing ZTF18aaydmkh....
#   Saved ZTF18aaydmkh_lightcurve_salt2.png  (114/425 completed)
# [116/425] Processing ZTF18aayiahw....
#   Saved ZTF18aayiahw_lightcurve_salt2.png  (115/425 completed)
# [117/425] Processing ZTF18aayidfz....
#   Saved ZTF18aayidfz_lightcurve_salt2.png  (116/425 completed)
# [118/425] Processing ZTF18aayjvve....
#   Saved ZTF18aayjvve_lightcurve_salt2.png  (117/425 completed)
# [119/425] Processing ZTF18aayjyub....
#   Saved ZTF18aayjyub_lightcurve_salt2.png  (118/425 completed)
# [120/425] Processing ZTF18aayyqia....
#   Saved ZTF18aayyqia_lightcurve_salt2.png  (119/425 completed)
# [121/425] Processing ZTF18aazabmh....
#   Saved ZTF18aazabmh_lightcurve_salt2.png  (120/425 completed)
# [122/425] Processing ZTF18aazblzy....
#   Saved ZTF18aazblzy_lightcurve_salt2.png  (121/425 completed)
# [123/425] Processing ZTF18aazhwnh....
#   Saved ZTF18aazhwnh_lightcurve_salt2.png  (122/425 completed)
# [124/425] Processing ZTF18aazixbw....
#   Saved ZTF18aazixbw_lightcurve_salt2.png  (123/425 completed)
# [125/425] Processing ZTF18aazjqil....
#   Saved ZTF18aazjqil_lightcurve_salt2.png  (124/425 completed)
# [126/425] Processing ZTF18aazjztm....
#   Saved ZTF18aazjztm_lightcurve_salt2.png  (125/425 completed)
# [127/425] Processing ZTF18aazsabq....
#   Saved ZTF18aazsabq_lightcurve_salt2.png  (126/425 completed)
# [128/425] Processing ZTF18abakunn....
#   Saved ZTF18abakunn_lightcurve_salt2.png  (127/425 completed)
# [129/425] Processing ZTF18abavruc....
#   Saved ZTF18abavruc_lightcurve_salt2.png  (128/425 completed)
# [130/425] Processing ZTF18abaxlpi....
#   Saved ZTF18abaxlpi_lightcurve_salt2.png  (129/425 completed)
# [131/425] Processing ZTF18abbpeqo....
#   Saved ZTF18abbpeqo_lightcurve_salt2.png  (130/425 completed)
# [132/425] Processing ZTF18abbqjds....
#   Saved ZTF18abbqjds_lightcurve_salt2.png  (131/425 completed)
# [133/425] Processing ZTF18abbvsiv....
#   Saved ZTF18abbvsiv_lightcurve_salt2.png  (132/425 completed)
# [134/425] Processing ZTF18abcdzyc....
#   Saved ZTF18abcdzyc_lightcurve_salt2.png  (133/425 completed)
# [135/425] Processing ZTF18abcecfi....
#   Saved ZTF18abcecfi_lightcurve_salt2.png  (134/425 completed)
# [136/425] Processing ZTF18abcflnz....
#   Saved ZTF18abcflnz_lightcurve_salt2.png  (135/425 completed)
# [137/425] Processing ZTF18abckujg....
#   Saved ZTF18abckujg_lightcurve_salt2.png  (136/425 completed)
# [138/425] Processing ZTF18abckujq....
#   Saved ZTF18abckujq_lightcurve_salt2.png  (137/425 completed)
# [139/425] Processing ZTF18abcrtnq....
#   Saved ZTF18abcrtnq_lightcurve_salt2.png  (138/425 completed)
# [140/425] Processing ZTF18abcrxoj....
#   Saved ZTF18abcrxoj_lightcurve_salt2.png  (139/425 completed)
# [141/425] Processing ZTF18abcsgvj....
#   Saved ZTF18abcsgvj_lightcurve_salt2.png  (140/425 completed)
# [142/425] Processing ZTF18abcvush....
#   Saved ZTF18abcvush_lightcurve_salt2.png  (141/425 completed)
# [143/425] Processing ZTF18abcysdx....
#   Saved ZTF18abcysdx_lightcurve_salt2.png  (142/425 completed)
# [144/425] Processing ZTF18abdbuty....
#   Saved ZTF18abdbuty_lightcurve_salt2.png  (143/425 completed)
# [145/425] Processing ZTF18abdcudb....
#   Saved ZTF18abdcudb_lightcurve_salt2.png  (144/425 completed)
# [146/425] Processing ZTF18abddrhd....
#   Saved ZTF18abddrhd_lightcurve_salt2.png  (145/425 completed)
# [147/425] Processing ZTF18abdefet....
#   Saved ZTF18abdefet_lightcurve_salt2.png  (146/425 completed)
# [148/425] Processing ZTF18abdfazk....
#   Saved ZTF18abdfazk_lightcurve_salt2.png  (147/425 completed)
# [149/425] Processing ZTF18abdfwur....
#   Saved ZTF18abdfwur_lightcurve_salt2.png  (148/425 completed)
# [150/425] Processing ZTF18abdfydj....
#   Saved ZTF18abdfydj_lightcurve_salt2.png  (149/425 completed)
# [151/425] Processing ZTF18abdgwxn....
#   Saved ZTF18abdgwxn_lightcurve_salt2.png  (150/425 completed)
# [152/425] Processing ZTF18abdiwpt....
#   Saved ZTF18abdiwpt_lightcurve_salt2.png  (151/425 completed)
# [153/425] Processing ZTF18abdkimx....
#   Saved ZTF18abdkimx_lightcurve_salt2.png  (152/425 completed)
# [154/425] Processing ZTF18abdnffn....
#   Saved ZTF18abdnffn_lightcurve_salt2.png  (153/425 completed)
# [155/425] Processing ZTF18abdnihj....
#   Saved ZTF18abdnihj_lightcurve_salt2.png  (154/425 completed)
# [156/425] Processing ZTF18abdrmin....
#   Saved ZTF18abdrmin_lightcurve_salt2.png  (155/425 completed)
# [157/425] Processing ZTF18abeecwe....
#   Saved ZTF18abeecwe_lightcurve_salt2.png  (156/425 completed)
# [158/425] Processing ZTF18abeegsl....
#   Saved ZTF18abeegsl_lightcurve_salt2.png  (157/425 completed)
# [159/425] Processing ZTF18abespgb....
#   Saved ZTF18abespgb_lightcurve_salt2.png  (158/425 completed)
# [160/425] Processing ZTF18abetehf....
#   Saved ZTF18abetehf_lightcurve_salt2.png  (159/425 completed)
# [161/425] Processing ZTF18abetejo....
#   Skip ZTF18abetejo: too few points (3)
# [162/425] Processing ZTF18abetewu....
#   Saved ZTF18abetewu_lightcurve_salt2.png  (160/425 completed)
# [163/425] Processing ZTF18abfbbyh....
#   Saved ZTF18abfbbyh_lightcurve_salt2.png  (161/425 completed)
# [164/425] Processing ZTF18abfchzq....
#   Saved ZTF18abfchzq_lightcurve_salt2.png  (162/425 completed)
# [165/425] Processing ZTF18abfdupq....
#   Saved ZTF18abfdupq_lightcurve_salt2.png  (163/425 completed)
# [166/425] Processing ZTF18abfeyey....
#   Saved ZTF18abfeyey_lightcurve_salt2.png  (164/425 completed)
# [167/425] Processing ZTF18abffdjl....
#   Saved ZTF18abffdjl_lightcurve_salt2.png  (165/425 completed)
# [168/425] Processing ZTF18abffdpa....
#   Saved ZTF18abffdpa_lightcurve_salt2.png  (166/425 completed)
# [169/425] Processing ZTF18abfgygp....
#   Saved ZTF18abfgygp_lightcurve_salt2.png  (167/425 completed)
# [170/425] Processing ZTF18abfhaji....
#   Saved ZTF18abfhaji_lightcurve_salt2.png  (168/425 completed)
# [171/425] Processing ZTF18abfhryc....
#   Saved ZTF18abfhryc_lightcurve_salt2.png  (169/425 completed)
# [172/425] Processing ZTF18abfwuwn....
#   Saved ZTF18abfwuwn_lightcurve_salt2.png  (170/425 completed)
# [173/425] Processing ZTF18abgkjff....
#   Saved ZTF18abgkjff_lightcurve_salt2.png  (171/425 completed)
# [174/425] Processing ZTF18abgqkpc....
#   Saved ZTF18abgqkpc_lightcurve_salt2.png  (172/425 completed)
# [175/425] Processing ZTF18abgxkzx....
#   Saved ZTF18abgxkzx_lightcurve_salt2.png  (173/425 completed)
# [176/425] Processing ZTF18abgxvra....
#   Saved ZTF18abgxvra_lightcurve_salt2.png  (174/425 completed)
# [177/425] Processing ZTF18abhbqbh....
#   Saved ZTF18abhbqbh_lightcurve_salt2.png  (175/425 completed)
# [178/425] Processing ZTF18abiczpm....
#   Saved ZTF18abiczpm_lightcurve_salt2.png  (176/425 completed)
# [179/425] Processing ZTF18abifioh....
#   Saved ZTF18abifioh_lightcurve_salt2.png  (177/425 completed)
# [180/425] Processing ZTF18abimsyv....
#   Saved ZTF18abimsyv_lightcurve_salt2.png  (178/425 completed)
# [181/425] Processing ZTF18abixkjh....
#   Saved ZTF18abixkjh_lightcurve_salt2.png  (179/425 completed)
# [182/425] Processing ZTF18abixrei....
#   Saved ZTF18abixrei_lightcurve_salt2.png  (180/425 completed)
# [183/425] Processing ZTF18abjgyyr....
#   Saved ZTF18abjgyyr_lightcurve_salt2.png  (181/425 completed)
# [184/425] Processing ZTF18abjrfqx....
#   Saved ZTF18abjrfqx_lightcurve_salt2.png  (182/425 completed)
# [185/425] Processing ZTF18abjstcm....
#   Saved ZTF18abjstcm_lightcurve_salt2.png  (183/425 completed)
# [186/425] Processing ZTF18abjtgdo....
#   Saved ZTF18abjtgdo_lightcurve_salt2.png  (184/425 completed)
# [187/425] Processing ZTF18abjtger....
#   Saved ZTF18abjtger_lightcurve_salt2.png  (185/425 completed)
# [188/425] Processing ZTF18abjvhec....
#   Saved ZTF18abjvhec_lightcurve_salt2.png  (186/425 completed)
# [189/425] Processing ZTF18abjwahi....
#   Saved ZTF18abjwahi_lightcurve_salt2.png  (187/425 completed)
# [190/425] Processing ZTF18abkhcrj....
#   Saved ZTF18abkhcrj_lightcurve_salt2.png  (188/425 completed)
# [191/425] Processing ZTF18abkhcwl....
#   Saved ZTF18abkhcwl_lightcurve_salt2.png  (189/425 completed)
# [192/425] Processing ZTF18abkifng....
#   Saved ZTF18abkifng_lightcurve_salt2.png  (190/425 completed)
# [193/425] Processing ZTF18abktphg....
#   Saved ZTF18abktphg_lightcurve_salt2.png  (191/425 completed)
# [194/425] Processing ZTF18abkudjo....
#   Saved ZTF18abkudjo_lightcurve_salt2.png  (192/425 completed)
# [195/425] Processing ZTF18ablhvfr....
#   Saved ZTF18ablhvfr_lightcurve_salt2.png  (193/425 completed)
# [196/425] Processing ZTF18ablmflp....
#   Saved ZTF18ablmflp_lightcurve_salt2.png  (194/425 completed)
# [197/425] Processing ZTF18ablongw....
#   Saved ZTF18ablongw_lightcurve_salt2.png  (195/425 completed)
# [198/425] Processing ZTF18ablqjul....
#   Saved ZTF18ablqjul_lightcurve_salt2.png  (196/425 completed)
# [199/425] Processing ZTF18ablqkud....
#   Saved ZTF18ablqkud_lightcurve_salt2.png  (197/425 completed)
# [200/425] Processing ZTF18ablqlzp....
#   Saved ZTF18ablqlzp_lightcurve_salt2.png  (198/425 completed)
# [201/425] Processing ZTF18ablqqqp....
#   Saved ZTF18ablqqqp_lightcurve_salt2.png  (199/425 completed)
# [202/425] Processing ZTF18ablrljh....
#   Saved ZTF18ablrljh_lightcurve_salt2.png  (200/425 completed)
# [203/425] Processing ZTF18abltaxf....
#   Saved ZTF18abltaxf_lightcurve_salt2.png  (201/425 completed)
# [204/425] Processing ZTF18ablwtkf....
#   Saved ZTF18ablwtkf_lightcurve_salt2.png  (202/425 completed)
# [205/425] Processing ZTF18abmjvpb....
#   Saved ZTF18abmjvpb_lightcurve_salt2.png  (203/425 completed)
# [206/425] Processing ZTF18abmjvuf....
#   Saved ZTF18abmjvuf_lightcurve_salt2.png  (204/425 completed)
# [207/425] Processing ZTF18abmjyvo....
#   Saved ZTF18abmjyvo_lightcurve_salt2.png  (205/425 completed)
# [208/425] Processing ZTF18abmmdif....
#   Saved ZTF18abmmdif_lightcurve_salt2.png  (206/425 completed)
# [209/425] Processing ZTF18abmmkaz....
#   Saved ZTF18abmmkaz_lightcurve_salt2.png  (207/425 completed)
# [210/425] Processing ZTF18abmoung....
#   Saved ZTF18abmoung_lightcurve_salt2.png  (208/425 completed)
# [211/425] Processing ZTF18abmrhom....
#   Saved ZTF18abmrhom_lightcurve_salt2.png  (209/425 completed)
# [212/425] Processing ZTF18abmwnov....
#   Saved ZTF18abmwnov_lightcurve_salt2.png  (210/425 completed)
# [213/425] Processing ZTF18abmxahs....
#   Saved ZTF18abmxahs_lightcurve_salt2.png  (211/425 completed)
# [214/425] Processing ZTF18abmxdhb....
#   Saved ZTF18abmxdhb_lightcurve_salt2.png  (212/425 completed)
# [215/425] Processing ZTF18abmxfrc....
#   Saved ZTF18abmxfrc_lightcurve_salt2.png  (213/425 completed)
# [216/425] Processing ZTF18abmxmsv....
#   Saved ZTF18abmxmsv_lightcurve_salt2.png  (214/425 completed)
# [217/425] Processing ZTF18abncimo....
#   Saved ZTF18abncimo_lightcurve_salt2.png  (215/425 completed)
# [218/425] Processing ZTF18abntsgz....
#   Saved ZTF18abntsgz_lightcurve_salt2.png  (216/425 completed)
# [219/425] Processing ZTF18abnxhmc....
#   Saved ZTF18abnxhmc_lightcurve_salt2.png  (217/425 completed)
# [220/425] Processing ZTF18abobkii....
#   Saved ZTF18abobkii_lightcurve_salt2.png  (218/425 completed)
# [221/425] Processing ZTF18abokpvh....
#   Saved ZTF18abokpvh_lightcurve_salt2.png  (219/425 completed)
# [222/425] Processing ZTF18abpamut....
#   Saved ZTF18abpamut_lightcurve_salt2.png  (220/425 completed)
# [223/425] Processing ZTF18abpaywm....
#   Saved ZTF18abpaywm_lightcurve_salt2.png  (221/425 completed)
# [224/425] Processing ZTF18abpmmpo....
#   Saved ZTF18abpmmpo_lightcurve_salt2.png  (222/425 completed)
# [225/425] Processing ZTF18abpttky....
#   Saved ZTF18abpttky_lightcurve_salt2.png  (223/425 completed)
# [226/425] Processing ZTF18abqlpgq....
#   Saved ZTF18abqlpgq_lightcurve_salt2.png  (224/425 completed)
# [227/425] Processing ZTF18abquher....
#   Saved ZTF18abquher_lightcurve_salt2.png  (225/425 completed)
# [228/425] Processing ZTF18abqyaix....
#   Saved ZTF18abqyaix_lightcurve_salt2.png  (226/425 completed)
# [229/425] Processing ZTF18abqycit....
#   Saved ZTF18abqycit_lightcurve_salt2.png  (227/425 completed)
# [230/425] Processing ZTF18abrebsb....
#   Saved ZTF18abrebsb_lightcurve_salt2.png  (228/425 completed)
# [231/425] Processing ZTF18abrfccm....
#   Saved ZTF18abrfccm_lightcurve_salt2.png  (229/425 completed)
# [232/425] Processing ZTF18abrqedj....
#   Saved ZTF18abrqedj_lightcurve_salt2.png  (230/425 completed)
# [233/425] Processing ZTF18abrzeym....
#   Saved ZTF18abrzeym_lightcurve_salt2.png  (231/425 completed)
# [234/425] Processing ZTF18absdgon....
#   Saved ZTF18absdgon_lightcurve_salt2.png  (232/425 completed)
# [235/425] Processing ZTF18absnqyo....
#   Saved ZTF18absnqyo_lightcurve_salt2.png  (233/425 completed)
# [236/425] Processing ZTF18absspcp....
#   Saved ZTF18absspcp_lightcurve_salt2.png  (234/425 completed)
# [237/425] Processing ZTF18abtnlik....
#   Saved ZTF18abtnlik_lightcurve_salt2.png  (235/425 completed)
# [238/425] Processing ZTF18abugthp....
#   Saved ZTF18abugthp_lightcurve_salt2.png  (236/425 completed)
# [239/425] Processing ZTF18abwkzuc....
#   Saved ZTF18abwkzuc_lightcurve_salt2.png  (237/425 completed)
# [240/425] Processing ZTF18abxdkni....
#   Saved ZTF18abxdkni_lightcurve_salt2.png  (238/425 completed)
# [241/425] Processing ZTF18abxhaop....
#   Saved ZTF18abxhaop_lightcurve_salt2.png  (239/425 completed)
# [242/425] Processing ZTF18abxhsyn....
#   Saved ZTF18abxhsyn_lightcurve_salt2.png  (240/425 completed)
# [243/425] Processing ZTF18abxmxbh....
#   Saved ZTF18abxmxbh_lightcurve_salt2.png  (241/425 completed)
# [244/425] Processing ZTF18abxrqod....
#   Saved ZTF18abxrqod_lightcurve_salt2.png  (242/425 completed)
# [245/425] Processing ZTF18abxtoqz....
#   Saved ZTF18abxtoqz_lightcurve_salt2.png  (243/425 completed)
# [246/425] Processing ZTF18abxtvqc....
#   Saved ZTF18abxtvqc_lightcurve_salt2.png  (244/425 completed)
# [247/425] Processing ZTF18abzzkyg....
#   Saved ZTF18abzzkyg_lightcurve_salt2.png  (245/425 completed)
# [248/425] Processing ZTF18acacnmr....
#   Skip ZTF18acacnmr: too few points (3)
# [249/425] Processing ZTF18acaezsx....
#   Saved ZTF18acaezsx_lightcurve_salt2.png  (246/425 completed)
# [250/425] Processing ZTF18acbvcmw....
#   Saved ZTF18acbvcmw_lightcurve_salt2.png  (247/425 completed)
# [251/425] Processing ZTF18acbvgqw....
#   Saved ZTF18acbvgqw_lightcurve_salt2.png  (248/425 completed)
# [252/425] Processing ZTF18acbxmvy....
#   Saved ZTF18acbxmvy_lightcurve_salt2.png  (249/425 completed)
# [253/425] Processing ZTF18acbxsap....
#   Saved ZTF18acbxsap_lightcurve_salt2.png  (250/425 completed)
# [254/425] Processing ZTF18acbxsge....
#   Saved ZTF18acbxsge_lightcurve_salt2.png  (251/425 completed)
# [255/425] Processing ZTF18acbyyff....
#   Saved ZTF18acbyyff_lightcurve_salt2.png  (252/425 completed)
# [256/425] Processing ZTF18accjdgs....
#   Saved ZTF18accjdgs_lightcurve_salt2.png  (253/425 completed)
# [257/425] Processing ZTF18acclexy....
#   Saved ZTF18acclexy_lightcurve_salt2.png  (254/425 completed)
# [258/425] Processing ZTF18accndxn....
#   Saved ZTF18accndxn_lightcurve_salt2.png  (255/425 completed)
# [259/425] Processing ZTF18accnlji....
#   Saved ZTF18accnlji_lightcurve_salt2.png  (256/425 completed)
# [260/425] Processing ZTF18accrorf....
#   Saved ZTF18accrorf_lightcurve_salt2.png  (257/425 completed)
# [261/425] Processing ZTF18accsawg....
#   Saved ZTF18accsawg_lightcurve_salt2.png  (258/425 completed)
# [262/425] Processing ZTF18accwjiu....
#   Saved ZTF18accwjiu_lightcurve_salt2.png  (259/425 completed)
# [263/425] Processing ZTF18acdwuhy....
#   Saved ZTF18acdwuhy_lightcurve_salt2.png  (260/425 completed)
# [264/425] Processing ZTF18acdyypo....
#   Saved ZTF18acdyypo_lightcurve_salt2.png  (261/425 completed)
# [265/425] Processing ZTF18aceexmi....
#   Saved ZTF18aceexmi_lightcurve_salt2.png  (262/425 completed)
# [266/425] Processing ZTF18acefhxx....
#   Saved ZTF18acefhxx_lightcurve_salt2.png  (263/425 completed)
# [267/425] Processing ZTF18acefxko....
#   Saved ZTF18acefxko_lightcurve_salt2.png  (264/425 completed)
# [268/425] Processing ZTF18acemhyb....
#   Saved ZTF18acemhyb_lightcurve_salt2.png  (265/425 completed)
# [269/425] Processing ZTF18aceyjco....
#   Saved ZTF18aceyjco_lightcurve_salt2.png  (266/425 completed)
# [270/425] Processing ZTF18aceynvm....
#   Saved ZTF18aceynvm_lightcurve_salt2.png  (267/425 completed)
# [271/425] Processing ZTF18acfwmqj....
#   Saved ZTF18acfwmqj_lightcurve_salt2.png  (268/425 completed)
# [272/425] Processing ZTF18achxcsh....
#   Saved ZTF18achxcsh_lightcurve_salt2.png  (269/425 completed)
# [273/425] Processing ZTF18acjxyak....
#   Saved ZTF18acjxyak_lightcurve_salt2.png  (270/425 completed)
# [274/425] Processing ZTF18acmyxfx....

# %%
# Output CSV of sncosmo parameters
if all_results:
    params_df = pd.DataFrame(all_results)
    out_csv = run_folder / "sncosmo_parameters.csv"
    params_df.to_csv(out_csv, index=False)
    print(f"Saved sncosmo parameters to {out_csv}")
    display(params_df)
else:
    print("No successful fits to write.")
# Out:
# Saved sncosmo parameters to /Users/david/Code/msc/runs/test4/sncosmo_parameters.csv
#        object_id        chisq  ndof        z            t0        x0  \
# 0   ZTF19aailqir     1.707646     7  0.05434  58529.181776  0.000451
# 1   ZTF19aailqli    86.067663    19  0.05800  58535.586380  0.001421
# 2   ZTF19aailteb    16.736875     8  0.07800  58524.495481  0.000763
# 3   ZTF19aailuvj     4.448203    14  0.07100  58536.547675  0.000903
# 4   ZTF19aajwdqt    16.834560    13  0.08800  58538.834603  0.000837
# 5   ZTF19aajwhbc     0.253676     1  0.10000  58536.914900  0.000563
# 6   ZTF19aajxhwa    14.489825    18  0.03300  58539.506247  0.003617
# 7   ZTF19aajxwnz  2948.340692    73  0.01500  58544.708295  0.020554
# 8   ZTF19aakiwxx     6.581250    30  0.04500  58537.073989  0.002080
# 9   ZTF19aakiyly    57.217998    17  0.07000  58539.562164  0.001059
# 10  ZTF19aakjbej     1.318554     6  0.08960  58536.931128  0.000534
# 11  ZTF19aaklbok     2.367481     4  0.08000  58539.827890  0.000739
# 12  ZTF19aakljys     9.966310    12  0.04396  58538.993552  0.001212
# 13  ZTF19aaklqod   317.674929    32  0.03000  58904.149406  0.003282
# 14  ZTF19aaklquv   213.176649    19  0.04860  58540.115799  0.001628
# 15  ZTF19aaknign     2.865809     7  0.09575  58546.872553  0.000522
# 16  ZTF19aakpfax     7.348896    16  0.07990  58544.157348  0.000352
# 17  ZTF19aaksrgj     8.915083    22  0.08590  58549.861397  0.000545
# 18  ZTF19aakthjl     2.976090    14  0.06075  58548.848064  0.000730
# 19  ZTF19aakzwao  2148.987781    60  0.01951  58556.234800  0.006146
# 20  ZTF19aalcwjt     5.777529     9  0.06700  58551.716135  0.000630
# 21  ZTF19aalcyfd   163.157368    24  0.03518  58553.468550  0.003845
# 22  ZTF19aaldqvh     4.874955    13  0.10100  58546.394502  0.000454
# 23  ZTF19aaleptm     5.321613    18  0.07900  58554.447881  0.000568
# 24  ZTF19aaljcsu     1.933175     4  0.05000  58549.233743  0.001045
# 25  ZTF19aalpoff   118.154915    14  0.02116  60790.200456  0.004209
# 26  ZTF19aaluprf     4.753352     9  0.09000  58558.643994  0.000976
# 27  ZTF19aalveag    34.195835    15  0.05000  58557.616939  0.001048
# 28  ZTF19aalxcyo     0.952278     7  0.08020  58551.439777  0.000607
# 29  ZTF19aalxlpp     4.358314     9  0.08600  58559.602409  0.000621
# 30  ZTF19aalyleg     0.933933     3  0.07100  58559.681435  0.000710
# 31  ZTF19aalzmio    49.631757    28  0.07500  58562.901528  0.001172
# 32  ZTF19aalzmiu     5.479067    19  0.11000  58557.996410  0.000556
# 33  ZTF19aamaeve     4.049950    12  0.07200  58555.747031  0.000906
# 34  ZTF19aambfxc  1656.089051    75  0.05500  58889.430517  0.001691
# 35  ZTF19aamgokq     1.163197    11  0.08000  58563.548305  0.000755
# 36  ZTF19aamgttu     9.821636    14  0.03080  58567.379461  0.003123
# 37  ZTF19aamhhae   416.268327    33  0.04000  58569.766888  0.001851
# 38  ZTF19aamhhey   416.163858    32  0.04500  58567.629508  0.002123
# 39  ZTF19aamhhgu    27.926033    18  0.03820  58568.194175  0.001493
# 40  ZTF19aamhhyo     7.922146    29  0.08000  58568.014288  0.000593
# 41  ZTF19aamhlnl     3.775889    10  0.07600  58566.280644  0.000673
# 42  ZTF19aamhqej  5155.924437    72  0.01690  58570.479651  0.014142
#
#           x1         c     mwebv    t0_err    x0_err    x1_err     c_err
# 0   0.139796  0.300000  0.024839  0.539645  0.000021  0.731697  0.413524
# 1   0.197938 -0.039584  0.013871  0.240893  0.000094  0.368545  0.047733
# 2   2.999994 -0.036656  0.014516  0.835964  0.000040  0.974345  0.053904
# 3   0.470430 -0.094157  0.021290  0.313551  0.000059  0.422184  0.047706
# 4   3.000000  0.029961  0.046129  0.333009  0.000039  0.171656  0.046427
# 5  -0.571901 -0.139275  0.013871  2.106258  0.000348  4.021764  0.339512
# 6   0.403831 -0.061157  0.206129  0.229294  0.000106  0.298906  0.028861
# 7   0.849131  0.042802  0.154194  0.066075  0.000327  0.084007  0.011186
# 8  -1.004063 -0.063543  0.016452  0.172475  0.000072  0.175499  0.028095
# 9   0.666689 -0.072604  0.028065  0.307995  0.000049  0.304747  0.038799
# 10  1.954350 -0.137203  0.018710  1.305319  0.000050  1.117280  0.110628
# 11  2.919043 -0.009219  0.046452  1.598207  0.000078  5.665879  0.087842
# 12 -1.764000  0.029057  0.016129  0.562460  0.000058  0.365036  0.043161
# 13 -2.527358 -0.065478  0.025806  0.104342  0.000054  0.197204  0.014719
# 14  1.056654  0.030193  0.025806  1.174896  0.000076  0.564595  0.041702
# 15  0.443363 -0.015887  0.037419  0.656540  0.000034  0.704314  0.062997
# 16  0.088793  0.227792  0.024516  0.927400  0.000025  0.731898  0.060394
# 17  1.501015  0.039210  0.021935  0.532997  0.000025  0.506253  0.043275
# 18 -0.185142  0.089586  0.018387  0.528474  0.000033  0.501899  0.050122
# 19  0.240500  0.070724  0.009032  0.085645  0.000110  0.101739  0.014323
# 20  0.006049  0.059479  0.022258  0.447566  0.000061  0.685658  0.076305
# 21 -0.101871 -0.089318  0.016774  0.000137  0.000099  0.146408  0.020640
# 22  0.729314  0.025460  0.011935  0.912687  0.000027  0.829664  0.058512
# 23 -0.355444  0.029695  0.023548  0.322848  0.000035  0.363142  0.050138
# 24 -1.250869  0.199263  0.073548  0.421448  0.000105  0.896981  0.073591
# 25 -2.145185  0.225159  0.042258  0.115053  0.000081  0.142979  0.021075
# 26 -1.031020  0.011250  0.041290  0.415814  0.000063  0.420558  0.058301
# 27 -1.065806 -0.029693  0.017419  0.349054  0.000061  0.285223  0.047440
# 28  0.600808  0.103000  0.044839  0.668154  0.000041  0.856691  0.058877
# 29  1.162520 -0.026949  0.040645  0.472344  0.000035  0.597648  0.053707
# 30 -0.485022 -0.004224  0.120323  1.005743  0.000076  1.063634  0.106493
# 31  1.228828 -0.071194  0.017097  0.281548  0.000040  0.305084  0.029020
# 32  1.196632 -0.121881  0.014516  0.432213  0.000025  0.446956  0.043298
# 33  1.355753 -0.014727  0.035806  0.460084  0.000027  0.479806  0.036308
# 34 -0.030344 -0.029450  0.038065  0.148598  0.000039  0.198426  0.020800
# 35 -0.264778 -0.105166  0.032903  0.569401  0.000038  0.521718  0.049833
# 36 -2.102166  0.022067  0.036452  0.170435  0.000146  0.180374  0.036745
# 37  0.576610  0.025050  0.012903  0.169029  0.000047  0.186585  0.021645
# 38  1.028929  0.063173  0.009677  0.195928  0.000053  0.211541  0.021242
# 39 -2.493571  0.069097  0.009677  0.167410  0.000051  0.193584  0.029697
# 40 -0.194006 -0.029067  0.015161  0.347132  0.000022  0.340166  0.033024
# 41 -1.377174 -0.068374  0.027742  0.377599  0.000042  0.468022  0.053986
# 42 -0.732877 -0.026488  0.050968  0.067612  0.000252  0.078573  0.013879
