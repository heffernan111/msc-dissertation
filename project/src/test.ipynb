# %%
# %load_ext autoreload
# %autoreload 2

import sys
from pathlib import Path
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import sncosmo

# Setup paths
project_root = Path("/Users/david/Code/msc/project")
data_path = project_root / "data"
src_path = project_root / "src"
sys.path.append(str(src_path))

print(f"sncosmo version: {sncosmo.__version__}")
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
# sncosmo version: 2.12.1

# %%
# Load light curve data
ztf_id = "ZTF17aabtvsy"
lasair_csv_path = data_path / "lasair" / "ZTF17aacldgo_lightcurve.csv"

if not lasair_csv_path.exists():
    print(f"Error: {lasair_csv_path} not found.")
else:
    df = pd.read_csv(lasair_csv_path)
    print(f"Loaded {len(df)} data points for {ztf_id}")
    print(f"\nColumns: {df.columns.tolist()}")
    print(f"\nFirst few rows:")
    print(df.head())
# Out:
# Loaded 74 data points for ZTF17aabtvsy
#
# Columns: ['MJD', 'filter', 'unforced_mag', 'unforced_mag_error', 'unforced_mag_status', 'forced_ujy', 'forced_ujy_error']
#
# First few rows:
#             MJD filter  unforced_mag  unforced_mag_error unforced_mag_status  \
# 0  59863.447697      r     18.892401                 NaN            positive
# 1  59864.374745      r     19.051399                 NaN            positive
# 2  59864.398206      g     19.065701                 NaN            positive
# 3  59865.383449      r     19.438101                 NaN            positive
# 4  59865.400683      g     19.413000                 NaN            positive
#
#    forced_ujy  forced_ujy_error
# 0         NaN               NaN
# 1         NaN               NaN
# 2         NaN               NaN
# 3         NaN               NaN
# 4         NaN               NaN
